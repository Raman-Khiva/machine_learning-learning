# %% [markdown]
# <a href="https://colab.research.google.com/github/Raman-Khiva/machine_learning-learning/blob/main/Cholestrol_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cholestrol-regression project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
